# %% [markdown]
# ## 데이터 분석 기초
#
# ### Folium 지도
# - 자바스크립트 기반의 지도 라이브러리. Leaflet.js를 파이썬용으로 재개발
# - GitHub에서 바로 볼 수 없음
#
# #### 설치
# ```bash
# !pip install folium
# ```
#
# #### Folium 로딩 문제
# - 실행 시 Make this notebook trusted to load map : File -> Trust Notebook 발생
# - VS코드 설정(ctrl ,)  > 보안 > 작업영역 > trust enabled 체크해제
#     ![image.png](attachment:image.png)

# %%
# !pip install folium
# Out:
# ...
#   Using cached charset_normalizer-3.4.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# ...
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached charset_normalizer-3.4.6-cp312-cp312-win_amd64.whl (154 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# ...
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### 위경도 특성
# - 소수점 4자리 이상 작성해야 제대로 된 위치를 잡을 수 있음

# %%
# folium 라이브러리 로드
import folium

# %%
loc=[35.116336,129.090216]
m= folium.Map(location=loc,
              zoom_start=15,
              tiles ="CartoDB positron")   # 지도 객체 생성, m 변수 할당

# 마커를 생성해서 지도변수에 추가
folium.Marker(location=loc,
              tooltip='부산',
              popup='부경대 용당캠퍼스',
              icon=folium.Icon(icon='home')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 맵 타일 문제
# - 사용 중인 지도타일 서버의 접속 문제
# - OpenStreetMap 타일 서버를 다른 타일로 변경
#     - CartoDB positron
#     - CartoDB dark_matter
#     - 폴리움 기본 사이트 https://python-visualization.github.io/folium/latest/index.html
